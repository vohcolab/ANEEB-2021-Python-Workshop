# %%
# importing packages

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import re # regular expressions

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from Bio.SeqUtils.ProtParam import ProteinAnalysis

# %%
df=pd.read_excel(r'2020.01.12_Combined_Ti_1.xlsx')

# See dataframe head

df.head(3)
df.shape
# Out:
#    Row  User Flag    OK  Cmpd.   m/z meas.     Mr calc.  z  Δ m/z [ppm]  \
# 0    1        NaN  True   9938  508.753911  1523.610258  3     1.134868
# 1    2        NaN  True  17927  554.150198  1659.786917  3     0.068551
# 2    3        NaN  True  17891  554.150278  1659.786917  3     0.212885
#
#    RMS90 [ppm]   Rt [min]  ... #Cmpds.       Site  Rank  P  \
# 0     5.145389  26.586875  ...      45  99.966283     1  0
# 1     4.172535  37.918850  ...     678        NaN     1  0
# 2     4.125017  37.863750  ...     678        NaN     1  0
#
#              Sequence                        Modifications Type      Range  \
# 0    K.TVDMESTEVFTK.K  Acetyl: 1; Oxidation: 4; Phospho: 6  CID  153 - 164
# 1  K.VPQLEIVPNSAEER.L                          Phospho: 10  CID  121 - 134
# 2  K.VPQLEIVPNSAEER.L                          Phospho: 10  CID  121 - 134
#
#      Accession                                            Protein
# 0  CASA2_BOVIN  Alpha-S2-casein OS=Bos taurus GN=CSN1S2 PE=1 SV=2
# 1  CASA1_BOVIN  Alpha-S1-casein OS=Bos taurus GN=CSN1S1 PE=1 SV=2
# 2  CASA1_BOVIN  Alpha-S1-casein OS=Bos taurus GN=CSN1S1 PE=1 SV=2
#
# [3 rows x 21 columns]
# (2541, 21)

# %%
# useful columns
PTMS = df[["Site" , "Sequence", "Modifications", "Accession"]]

PTMS.head(3)
# Out:
#         Site            Sequence                        Modifications  \
# 0  99.966283    K.TVDMESTEVFTK.K  Acetyl: 1; Oxidation: 4; Phospho: 6
# 1        NaN  K.VPQLEIVPNSAEER.L                          Phospho: 10
# 2        NaN  K.VPQLEIVPNSAEER.L                          Phospho: 10
#
#      Accession
# 0  CASA2_BOVIN
# 1  CASA1_BOVIN
# 2  CASA1_BOVIN

# %% [markdown]
# Phospho seems to happen everytime.
#
# Let's get the distribution of aminoacids

# %%
# first get a cleaned version of the sequence column
PTMS = (PTMS
        .assign(cleaned_sequence = lambda row: (row
                                                .Sequence
                                                .apply(lambda seq : seq.split('.')[1])
                                               )
               )
       )
PTMS.head(3)
# Out:
#         Site            Sequence                        Modifications  \
# 0  99.966283    K.TVDMESTEVFTK.K  Acetyl: 1; Oxidation: 4; Phospho: 6
# 1        NaN  K.VPQLEIVPNSAEER.L                          Phospho: 10
# 2        NaN  K.VPQLEIVPNSAEER.L                          Phospho: 10
#
#      Accession cleaned_sequence
# 0  CASA2_BOVIN     TVDMESTEVFTK
# 1  CASA1_BOVIN   VPQLEIVPNSAEER
# 2  CASA1_BOVIN   VPQLEIVPNSAEER

# %%
def capture_phospho_positions(modification):
    """
    Given a modification description of the form:
    "Acetyl: 1; Oxidation: 4; Phospho: 6", captures the positions of the Phospho component only
    
    
    Returns a list of the positions.
    
    
    Example:
    
    example = "Acetyl: 1; Oxidation: 4; Phospho: 6"
    capture_phospho_positions(example)
    >>> [6]
    
    example_2 = "Acetyl: 5; Oxidation: 2; Phospho: 6, 9"
    capture_phospho_positions(example)
    >>> [6, 9]
    """
    
    
    events = modification.split(';')
    phospho_info = [s for s in events if 'Phospho' in s][0]
    
    # remove unecessary info ('Phospho:')
    positions_str = phospho_info[phospho_info.find(':')+1:]
    # remove whitespaces and get list of positions
    positions_list = positions_str.replace(" ", "").split(',')
    # convert positions to ints
    positions_list = [int(e) -1 for e in positions_list]
    
    return positions_list

# %%
PTMS['Letras'] = PTMS.apply(lambda row: np.array([char for char in row.cleaned_sequence])[capture_phospho_positions(row.Modifications)],axis=1)
PTMS.assign(TotalLetras = PTMS.Letras.apply(lambda x: len(x)),
            S = PTMS.Letras.apply(lambda letras: len([s for s in letras if s == 'S'])),
            T = PTMS.Letras.apply(lambda letras: len([s for s in letras if s == 'T'])),
            Y = PTMS.Letras.apply(lambda letras: len([s for s in letras if s == 'Y'])))
# Out:
#            Site                       Sequence  \
# 0     99.966283               K.TVDMESTEVFTK.K
# 1           NaN             K.VPQLEIVPNSAEER.L
# 2           NaN             K.VPQLEIVPNSAEER.L
# 3           NaN             K.VPQLEIVPNSAEER.L
# 4           NaN             K.VPQLEIVPNSAEER.L
# ...         ...                            ...
# 2536        NaN           K.YKVPQLEIVPNSAEER.L
# 2537        NaN           K.YKVPQLEIVPNSAEER.L
# 2538        NaN             K.VPQLEIVPNSAEER.L
# 2539        NaN           K.YKVPQLEIVPNSAEER.L
# 2540  33.333333  R.NANEEEYSIGSSSEESAEVATEEVK.I
#
#                             Modifications    Accession  \
# 0     Acetyl: 1; Oxidation: 4; Phospho: 6  CASA2_BOVIN
# 1                             Phospho: 10  CASA1_BOVIN
# 2                             Phospho: 10  CASA1_BOVIN
# 3                             Phospho: 10  CASA1_BOVIN
# 4                             Phospho: 10  CASA1_BOVIN
# ...                                   ...          ...
# 2536                          Phospho: 12  CASA1_BOVIN
# 2537                          Phospho: 12  CASA1_BOVIN
# 2538                          Phospho: 10  CASA1_BOVIN
# 2539                          Phospho: 12  CASA1_BOVIN
# 2540               Phospho: 8, 11, 12, 16  CASA2_BOVIN
#
#                cleaned_sequence        Letras  TotalLetras  S  T  Y
# 0                  TVDMESTEVFTK           [S]            1  1  0  0
# 1                VPQLEIVPNSAEER           [S]            1  1  0  0
# 2                VPQLEIVPNSAEER           [S]            1  1  0  0
# 3                VPQLEIVPNSAEER           [S]            1  1  0  0
# 4                VPQLEIVPNSAEER           [S]            1  1  0  0
# ...                         ...           ...          ... .. .. ..
# 2536           YKVPQLEIVPNSAEER           [S]            1  1  0  0
# 2537           YKVPQLEIVPNSAEER           [S]            1  1  0  0
# 2538             VPQLEIVPNSAEER           [S]            1  1  0  0
# 2539           YKVPQLEIVPNSAEER           [S]            1  1  0  0
# 2540  NANEEEYSIGSSSEESAEVATEEVK  [S, S, S, S]            4  4  0  0
#
# [2541 rows x 10 columns]
